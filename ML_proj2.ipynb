# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/satwikvutukuri/mllab/main/data2.csv')
df
# Out:
#    Example    Sky AirTemp Humidity    Wind Water Forecast EnjoySport
# 0        1  Sunny    Warm   Normal  Strong  Warm     Same        Yes
# 1        2  Sunny    Warm     High  Strong  Warm     Same        Yes
# 2        3  Rainy    Cold     High  Strong  Warm   Change         No
# 3        4  Sunny    Warm     High  Strong  Cool   Change        Yes

# %% [markdown]
# Data Extraction

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/satwikvutukuri/mllab/main/data2.csv')

y = df['EnjoySport']
y
# Out:
# 0    Yes
# 1    Yes
# 2     No
# 3    Yes
# Name: EnjoySport, dtype: object

# %% [markdown]
# taking the x values

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/satwikvutukuri/mllab/main/data2.csv')
d = df.values
x = d[:, :-1]
x
# Out:
# array([[1, 'Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same'],
#        [2, 'Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same'],
#        [3, 'Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change'],
#        [4, 'Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change']],
#       dtype=object)

# %% [markdown]
# taking the y values

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/satwikvutukuri/mllab/main/data2.csv')
training = df.values
y = d[:, -1]
y
# Out:
# array(['Yes', 'Yes', 'No', 'Yes'], dtype=object)

# %% [markdown]
# comparing x to y

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/satwikvutukuri/mllab/main/data2.csv')
training = df.values
target = training[:, -1]

def train(c,t):
    for i, val in enumerate(t):
        if val == "Yes":
            specific_hypothesis = c[i].copy()
            break

    for i, val in enumerate(c):
        if t[i] == "Yes":
            for x in range(len(specific_hypothesis)):
                if val[x] != specific_hypothesis[x]:
                    specific_hypothesis[x] = '?'
                else:
                    pass

    return specific_hypothesis

print("n The final hypothesis is:",train(training,target))
# Out:
# n The final hypothesis is: ['?' 'Sunny' 'Warm' '?' 'Strong' '?' '?' 'Yes']
